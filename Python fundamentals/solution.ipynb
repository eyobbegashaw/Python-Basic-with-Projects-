# %%
# 1.1

 
name = "Alice Johnson"
age = 20
grade = "A"
gpa = 3.8
is_international = False

print("Student Name:", name)
print("Age:", age)
print("Grade:", grade)
print("GPA:", gpa)
print("International Student:", is_international)

# 1.2
 
number_str = "100"
price_float = 49.99
is_valid = 1

# Convert them
number_int = int(number_str)
price_int = int(price_float)
price_str = str(price_float)
is_valid_bool = bool(is_valid)

print(f"String to int: {number_int} (type: {type(number_int)})")
print(f"Float to int: {price_int} (type: {type(price_int)})")
print(f"Float to string: {price_str} (type: {type(price_str)})")
print(f"Number to bool: {is_valid_bool} (type: {type(is_valid_bool)})")


# 1.3


a = 10
b = 20

print(f"Before swap: a = {a}, b = {b}")

# Swap using multiple assignment
a, b = b, a

print(f"After swap: a = {a}, b = {b}")

# Multiple variables in one line
x, y, z = 5, 10, 15
print(f"x = {x}, y = {y}, z = {z}")

# %%
# 2.1

 
num1 = 15
num2 = 4

# Perform all arithmetic operations
addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2
floor_division = num1 // num2
modulus = num1 % num2
exponent = num1 ** num2

print(f"{num1} + {num2} = {addition}")
print(f"{num1} - {num2} = {subtraction}")
print(f"{num1} * {num2} = {multiplication}")
print(f"{num1} / {num2} = {division}")
print(f"{num1} // {num2} = {floor_division}")
print(f"{num1} % {num2} = {modulus}")
print(f"{num1} ** {num2} = {exponent}")

# 2.2


age = 25
has_license = True
score = 85
attendance = 90

# Comparison operations
is_adult = age >= 18
is_senior = age >= 65
high_score = score >= 80
good_attendance = attendance >= 75

# Logical operations
can_drive = is_adult and has_license
gets_scholarship = high_score and good_attendance
special_category = is_senior or (score >= 90)

print(f"Can drive: {can_drive}")
print(f"Gets scholarship: {gets_scholarship}")
print(f"Special category: {special_category}")
print(f"Is adult: {is_adult}")
print(f"High score: {high_score}")

# 2.3

  
bank_balance = 1000
score = 50
counter = 0

print(f"Initial balance: ${bank_balance}")
print(f"Initial score: {score}")
print(f"Initial counter: {counter}")

# Update using compound operators
bank_balance += 500    # Deposit
bank_balance -= 200    # Withdrawal
bank_balance *= 1.05   # Interest
score += 10            # Bonus points
score -= 5             # Penalty
counter += 1           # Increment

print(f"Final balance: ${bank_balance}")
print(f"Final score: {score}")
print(f"Final counter: {counter}")

# %%
# 3.1

 
print("=== Personal Bio Data ===")

# Collect input
name = input("Enter your full name: ")
age = int(input("Enter your age: "))
city = input("Enter your city: ")
profession = input("Enter your profession: ")
hobby = input("Enter your hobby: ")

# Display formatted output
print("\n" + "="*30)
print("        BIO DATA")
print("="*30)
print(f"Name: {name}")
print(f"Age: {age} years old")
print(f"City: {city}")
print(f"Profession: {profession}")
print(f"Hobby: {hobby}")
print("="*30)

# 3.2


print("=== Advanced Calculator ===")

# Get numbers from user
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

# Perform calculations
sum_result = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2 if num2 != 0 else "Undefined (division by zero)"

# Display results with formatting
print("\n--- Calculation Results ---")
print(f"{num1} + {num2} = {sum_result:.2f}")
print(f"{num1} - {num2} = {difference:.2f}")
print(f"{num1} × {num2} = {product:.2f}")
print(f"{num1} ÷ {num2} = {quotient}")

# 3.3


print("=== Shopping Receipt Generator ===")

# Get item details
item_name = input("Enter item name: ")
price = float(input("Enter price per item: $"))
quantity = int(input("Enter quantity: "))
discount_percent = float(input("Enter discount percentage: "))

# Calculations
subtotal = price * quantity
discount_amount = subtotal * (discount_percent / 100)
tax_rate = 0.08  # 8% tax
tax_amount = (subtotal - discount_amount) * tax_rate
total = subtotal - discount_amount + tax_amount

# Generate receipt
print("\n" + "="*40)
print("           SHOPPING RECEIPT")
print("="*40)
print(f"Item: {item_name}")
print(f"Price: ${price:.2f} each")
print(f"Quantity: {quantity}")
print("-" * 40)
print(f"Subtotal: ${subtotal:.2f}")
print(f"Discount ({discount_percent}%): -${discount_amount:.2f}")
print(f"Tax (8%): ${tax_amount:.2f}")
print("=" * 40)
print(f"TOTAL: ${total:.2f}")
print("=" * 40)
print("Thank you for shopping with us!")
